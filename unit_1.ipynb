# %%
list = [1, 2, 3, None, (1, 2, 3, 4, 5), ['hello', 'how', 'are', 'you']]
print(len(list))
# Out:
# 6

# %%
a=int(input("enter"))
print(a+5)
type(a)
# Out:
# enter6
# 11
# int

# %%
L1 = []
L1.append([1, [2, 3], 4])
L1.extend([7, 8, 9])
print(L1[0][1][1] + L1[2])
# Out:
# 11

# %%
type(a)
# Out:
# str

# %%
id(a)  #memory address
# Out:
# 139651115758128

# %%
dir(a)  #returns all methods and properties associated with given object
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
#implicit type conversion
p=13
q=3
r=p/q
print(r)
type(r)
# Out:
# 4.333333333333333
# float

# %%
#explicit type conversion
m=13
n=3
o=int(m/n)
print(o)
type(o)
# Out:
# 4
# int

# %%
a=12.4
b=20
c='123.45'
print(int(a),complex(b),float(c))
# Out:
# 12 (20+0j) 123.45

# %%
a=input("Enter any number")
type(a)
# Out:
# Enter any number6
# str

# %%
a=str(input("enter your name:"))
print(a,b,sep="--",end='\n')
# Out:
# enter your name:ananya
# ananya--6

# %%
a=int(input("Enter 1st number:"))
b=int(input("enter 2nd number:"))
print(a+b)
# Out:
# Enter 1st number:12
# enter 2nd number:2
# 14

# %%
a=12
b=23.6
c='ABESEC'
print(a,b,c,sep='\n')
# Out:
# 12
# 23.6
# ABESEC

# %%
#floor division
a=14
b=3
print(a//b)
# Out:
# 4

# %%
#exponent
print(a**b)
print(a*a*a)
# Out:
# 2744
# 2744

# %%
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# True
# False
# False
# True
# True
# False

# %%
'hello'=='Hello'
# Out:
# False

# %%
'dog'!='cat'
# Out:
# True

# %%
50=='50'
# Out:
# False

# %%
25==25.4
# Out:
# False

# %%
a=9
b=3
print(a^b)
# Out:
# 10

# %%
#a<<b
#left shift operator a* (2^b)
3<<1
# Out:
# 6

# %%
3<<2
# Out:
# 12

# %%
3<<3
# Out:
# 24

# %%
#right shift operator a/(2^b)
#0 is inserted from left after right shifting of binary no.
#a>>b
8>>1
# Out:
# 4

# %%
8>>2
# Out:
# 2

# %%
# -ve number
#1 is inserted from left after right shifting
-3>>1
# Out:
# -2

# %%
#mode-> base--> press bin (log)
#calculator dec-->binary

# %%
#identity operator
a=10
b=10
c=12
print(a is b)
print(a is c)
print(a is not c)
# Out:
# True
# False
# True

# %%
#membership operator
spam=['blue','red','orange',21,55.5]
print('blue' in spam)
print('pink' in spam)
print(55.5 not in spam)
# Out:
# True
# False
# False
